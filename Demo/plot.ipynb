# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
b=pd.read_csv("two_state.csv")

# %%
b.time

# %%
fig = plt.figure()
plt.plot(b.time, b.time_diff)

#you can plot these all like this x_axis b.time
#b.time	b.velocity_1	b.elocity_2	b.effort_1	b.effort_2	b.position_1	b.position_2	b.acc_x	b.acc_y	b.acc_z	b.time_diff
